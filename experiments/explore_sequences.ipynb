# %%
import sys
from pathlib import Path

# Add project root to Python path (needed for notebooks)
project_root = Path(__file__).parent.parent if '__file__' in globals() else Path.cwd().parent
sys.path.insert(0, str(project_root))

import pandas as pd
from typing import Dict, Any, List, Tuple
from multiprocessing import Pool

from src.motzkin_greedy import optimize_motzkin_greedy
from src.smooth_walk_greedy import optimize_smooth_walk_greedy
from src.utils import P_from_d_prefix, parse_seed_list
from src.ssd_check import is_distinct_subset_sum_optimized
from src.sequence_analysis import generate_ssd_df, compare_and_save

# %%
d_seed = [3,1,2]
max_n = 25
compare_and_save(d_seed, max_n, optimizer=optimize_smooth_walk_greedy)
# Out:
# Returning cached result.
# ✓ Condition met! Saved to data/special_seeds/seed_3_1_2_n25.csv
# ✓ Condition met! Saved to data/special_seeds/seed_3_1_2_n25.csv
#     SSD        d        P   delta
# 0     1        3        3       2
# 1     1        1        4       2
# 2     1        2        6       2
# 3     1        2        8       1
# 4     1        8       16       3
# 5     1       12       28       4
# 6     1       22       50       6
# 7     1       44       94      10
# 8     1       78      172      11
# 9     1      156      328      19
# 10    1      300      628      34
# 11    1      578     1206      42
# 12    1     1112     2318      34
# 13    1     2224     4542      58
# 14    1     4370     8912     105
# 15    1     8584    17496     191
# 16    1    16868    34364      63
# 17    1    33158    67522    -486
# 18    1    66316   133838   -1014
# 19    1   131520   265358   -2062
# 20    1   260816   526174   -4182
# 21    1   517262  1043436   -8469
# 22    1  1025940  2069376  -25627
# 23    1  2035012  4104388  -68313
# 24    1  4070024  8174412 -136689

# %%
d_seed = [2, 1]

max_n = 27
d_seed_reference = [1, 1]

df_reference = generate_ssd_df(d_seed_reference, max_n)
df = generate_ssd_df(d_seed, max_n)
df = df.join(df_reference.set_index('n'), on='n', lsuffix='_new', rsuffix='_ref')
df['maxp_delta'] = df['maxP_new'] - df['maxP_ref']
print(df[['SSD_flag_new','n','d_n_ref','d_n_new','maxP_ref','maxP_new','maxp_delta']])
# Out:
#     SSD_flag_new   n   d_n_ref   d_n_new  maxP_ref  maxP_new  maxp_delta
# 0              1   1         1         2         1         2           1
# 1              1   2         1         1         2         3           1
# 2              1   3         2         1         4         4           0
# 3              1   4         3         4         7         8           1
# 4              1   5         6         6        13        14           1
# 5              1   6        11        11        24        25           1
# 6              1   7        20        22        44        47           3
# 7              1   8        40        39        84        86           2
# 8              1   9        77        78       161       164           3
# 9              1  10       148       150       309       314           5
# 10             1  11       285       289       594       603           9
# 11             1  12       570       556      1164      1159          -5
# 12             1  13      1120      1112      2284      2271         -13
# 13             1  14      2200      2185      4484      4456         -28
# 14             1  15      4323      4292      8807      8748         -59
# 15             1  16      8498      8434     17305     17182        -123
# 16             1  17     16996     16579     34301     33761        -540
# 17             1  18     33707     33158     68008     66919       -1089
# 18             1  19     66844     65760    134852    132679       -2173
# 19             1  20    132568    130408    267420    263087       -4333
# 20             1  21    262936    258631    530356    521718       -8638
# 21             1  22    521549    512970   1051905   1034688      -17217
# 22             1  23   1043098   1017506   2095003   2052194      -42809
# 23             1  24   2077698   2035012   4172701   4087206      -85495
# 24             1  25   4138400   4053445   8311101   8140651     -170450
# 25             1  26   8243093   8073732  16554194  16214383     -339811
# 26             1  27  16419342  16081704  32973536  32296087     -677449

# %%
d_seed = [3, 2]

max_n = 20
d_seed_reference = [1, 1]

df_reference = generate_ssd_df(d_seed_reference, max_n)
df = generate_ssd_df(d_seed, max_n, optimizer=optimize_smooth_walk_greedy)
df = df.join(df_reference.set_index('n'), on='n', lsuffix='_new', rsuffix='_ref')
df['maxp_delta'] = df['maxP_new'] - df['maxP_ref']
print(df[['SSD_flag_new','n','d_n_ref','d_n_new','maxP_ref','maxP_new','maxp_delta']])
# Out:
= generate_ssd_df(d_seed, max_n, optimizer=optimize_smooth_walk_greedy)
df = df.join(df_reference.set_index('n'), on='n', lsuffix='_new', rsuffix='_ref')
df['maxp_delta'] = df['maxP_new'] - df['maxP_ref']
print(df[['SSD_flag_new','n','d_n_ref','d_n_new','maxP_ref','maxP_new','maxp_delta']])
# Out:
#     SSD_flag_new   n  d_n_ref  d_n_new  maxP_ref  maxP_new  maxp_delta
# 0              1   1        1        4         1         4           3
# 1              1   2        1        1         2         5           3
# 2              1   3        2        1         4         6           2
# 3              1   4        3        2         7         8           1
# 4              1   5        6        8        13        16           3
# 5              1   6       11       11        24        27           3
# 6              1   7       20       22        44        49           5
# 7              1   8       40       43        84        92           8
# 8              1   9       77       76       161       168           7
# 9              1  10      148      152       309       320          11
# 10             1  11      285      293       594       613          19
# 11             1  12      570      564      1164      1177          13
# 12             1  13     1120     1085      2284      2262         -22
# 13             1  14     2200     2170      4484      4432         -52
# 14             1  15     4323     4264      8807      8696        -111
# 15             1  16     8498     8376     17305     17072        -233
# 16             1  17    16996    16459     34301     33531        -770
# 17             1  18    33707    32354     68008     65885       -2123
# 18             1  19    66844    64708    134852    130593       -4259
# 19             1  20   132568   128331    267420    258924       -8496
# 20             1  21   262936   254492    530356    513416      -16940
# 21             1  22   521549   504720   1051905   1018136      -33769
# 22             1  23  1043098  1001064   2095003   2019200      -75803
# 23             1  24  2077698  1985669   4172701   4004869     -167832
# 24             1  25  4138400  3971338   8311101   7976207     -334894

# %%
d_seed = [4,1,1,2]

max_n = 25


df = generate_ssd_df(d_seed, max_n, optimizer=optimize_smooth_walk_greedy)
df = df.join(df_reference.set_index('n'), on='n', lsuffix='_new', rsuffix='_ref')
df['maxp_delta'] = df['maxP_new'] - df['maxP_ref']

# Rename columns for display
display_df = df[['SSD_flag_new','d_n_new','maxP_new','maxp_delta']].copy()
display_df.columns = ['SSD', 'd', 'P', 'delta']
print(display_df)
# Out:
#     SSD        d        P   delta
# 0     1        4        4       3
# 1     1        1        5       3
# 2     1        1        6       2
# 3     1        2        8       1
# 4     1        8       16       3
# 5     1       11       27       3
# 6     1       22       49       5
# 7     1       43       92       8
# 8     1       76      168       7
# 9     1      152      320      11
# 10    1      293      613      19
# 11    1      564     1177      13
# 12    1     1085     2262     -22
# 13    1     2170     4432     -52
# 14    1     4264     8696    -111
# 15    1     8376    17072    -233
# 16    1    16459    33531    -770
# 17    1    32354    65885   -2123
# 18    1    64708   130593   -4259
# 19    1   128331   258924   -8496
# 20    1   254492   513416  -16940
# 21    1   504720  1018136  -33769
# 22    1  1001064  2019200  -75803
# 23    1  1985669  4004869 -167832
# 24    1  3971338  7976207 -334894
